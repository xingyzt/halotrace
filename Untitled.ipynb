# %%
import numpy as np

# %%
x = np.arange(1, 5)

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
y = x > 2
y
# Out:
# array([False, False,  True,  True])

# %%
z = ~y
z
# Out:
# array([ True,  True, False, False])
